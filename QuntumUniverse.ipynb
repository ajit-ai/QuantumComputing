# %% [markdown]
# <a href="https://colab.research.google.com/github/ajit-ai/QuantumComputing/blob/main/QuntumUniverse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit
# !pip install qiskit qiskit-aer
# !pip install qiskit-aer-gpu
# !pip install qiskit-aer-gpu-cu11
# !pip install --upgrade
# !pip install qiskit-aer

# Create and activate a new virtual environment (recommended)
# For Linux/macOS:
# !python3 -m venv .venv
# !source .venv/bin/activate

# Install Qiskit and Aer within the virtual environment
# !pip install qiskit[visualization] qiskit-aer

# You can also upgrade the versions if desired.
# The visualization extra is included to install matplotlib and other dependencies for plotting
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 44.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 MB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.0/109.0 kB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 89.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.9/156.9 MB 6.4 MB/s eta 0:00:00
# ...

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define our quantum system - we'll simulate 5 "particles" for simplicity
num_particles = 5
qr = QuantumRegister(num_particles)
cr = ClassicalRegister(num_particles)
circuit = QuantumCircuit(qr, cr)

# Superposition for all particles
for i in range(num_particles):
    circuit.h(qr[i])

# Simulate particle interactions (using entanglement to mimic gravitational effects)
for i in range(num_particles - 1):
    circuit.cx(qr[i], qr[i + 1])

# Apply phase gates to represent some influence (like gravity from a black hole)
for i in range(num_particles):
    circuit.p(np.pi/4, qr[i])

# Measure the system
circuit.measure(qr, cr)

# Simulate the circuit
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
result = job.result()
counts = result.get_counts(compiled_circuit)

# Visualize - let's create a 3D scatter plot where each point represents a particle state
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# For visualization, we'll use the binary state as a 3D coordinate
for state, count in counts.items():
    # Convert binary state to 3D coordinates for visualization
    # Here, we're assuming each qubit corresponds to an axis for simplicity
    #coords = [int(x) for x in state]
    coords = [int(x) for x in state[:3]]  # Limit coords to 3 values
    prob = count / 1000  # Normalize probability
    # Use probability to scale the size of the point
    ax.scatter(*coords, s=prob * 1000, alpha=0.5)

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('Simplified Quantum State Visualization for Dark Matter/Black Hole Effects')

plt.show()

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define our quantum system - 9 qubits for 9 "dimensions"
num_qubits = 9
qr = QuantumRegister(num_qubits)
cr = ClassicalRegister(num_qubits)
circuit = QuantumCircuit(qr, cr)

# Superposition for all qubits
for i in range(num_qubits):
    circuit.h(qr[i])

# Simulate interactions - here we'll use a very simple interaction model
for i in range(num_qubits - 1):
    circuit.cx(qr[i], qr[i + 1])  # Simplified entanglement to mimic interactions

# Apply phase gates to represent gravitational effects or dark matter influence
for i in range(num_qubits):
    circuit.p(np.pi/4, qr[i])

# Measure the system
circuit.measure(qr, cr)

# Simulate the circuit
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
result = job.result()
counts = result.get_counts(compiled_circuit)

# Visualization - We'll map 9D to 3D by grouping qubits
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for state, count in counts.items():
    # Map 9 qubits to 3D for visualization:
    # First 3 qubits for X, next 3 for Y, last 3 for Z
    x = sum(int(state[i]) * (2**i) for i in range(3))
    y = sum(int(state[i]) * (2**(i-3)) for i in range(3, 6))
    z = sum(int(state[i]) * (2**(i-6)) for i in range(6, 9))

    prob = count / 1000  # Normalize probability
    ax.scatter(x, y, z, s=prob * 1000, alpha=0.5)

ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
ax.set_title('Visualization of 9D Quantum States')

plt.show()

# %%
# !pip install matplotlib astropy mayavi
# !pip install configobj
# !pip install pyqt5





from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator
import numpy as np
from astropy.coordinates import CartesianRepresentation
from mayavi import mlab

# Define quantum system - 9 qubits for 9 "dimensions"
num_qubits = 9
qr = QuantumRegister(num_qubits)
cr = ClassicalRegister(num_qubits)
circuit = QuantumCircuit(qr, cr)

# Superposition for all qubits
for i in range(num_qubits):
    circuit.h(qr[i])

# Simulate interactions - simplified entanglement
for i in range(num_qubits - 1):
    circuit.cx(qr[i], qr[i + 1])

# Apply phase gates to represent gravitational effects or dark matter influence
for i in range(num_qubits):
    circuit.p(np.pi/4, qr[i])

# Measure the system
circuit.measure(qr, cr)

# Simulate the circuit
simulator = AerSimulator()
compiled_circuit = transpile(circuit, simulator)
job = simulator.run(compiled_circuit, shots=1000)
result = job.result()
counts = result.get_counts(compiled_circuit)

# Visualization - Map 9D to 3D for visualization
x, y, z = [], [], []
sizes = []

for state, count in counts.items():
    # Map 9 qubits to 3D for visualization:
    # We'll sum the first 3 bits for X, next 3 for Y, last 3 for Z
    x.append(sum(int(state[i]) * (2**i) for i in range(3)))
    y.append(sum(int(state[i]) * (2**(i-3)) for i in range(3, 6)))
    z.append(sum(int(state[i]) * (2**(i-6)) for i in range(6, 9)))
    sizes.append(count / 1000)  # Normalize probability

# Using Mayavi for 3D visualization
mlab.figure(bgcolor=(0, 0, 0), size=(800, 800))

# Create a 3D scatter plot
points = mlab.points3d(x, y, z, sizes, scale_mode='none', scale_factor=1.0,
                       colormap='viridis', mode='sphere')

# Add some interactivity
mlab.view(azimuth=45, elevation=70, distance=50)
mlab.colorbar(points, title="Probability", orientation='vertical')

# Add a title
mlab.title('Conceptual Visualization of 9D Quantum States for Dark Matter/Black Holes',
            size=0.3, height=0.9)

mlab.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-4736e2f69a3c> in <cell line: 0>()
#      54
#      55 # Using Mayavi for 3D visualization
# ---> 56 mlab.figure(bgcolor=(0, 0, 0), size=(800, 800))
#      57
#      58 # Create a 3D scatter plot
#
# /usr/local/lib/python3.11/dist-packages/mayavi/tools/figure.py in figure(figure, bgcolor, fgcolor, engine, size)
#      62     else:
#      63         if engine is None:
# ---> 64             engine = get_engine()
#      65         if figure is None:
#      66             name = max(__scene_number_list) + 1
#
# /usr/local/lib/python3.11/dist-packages/mayavi/tools/engine_manager.py in get_engine(self)
#      92                         if e.__class__.__name__ == 'Engine']
#      93         if len(suitable) == 0:
# ---> 94             return self.new_engine()
#      95         else:
# ...

# %%
from mayavi import mlab
import numpy as np

x, y, z = np.mgrid[-10:10:20j, -10:10:20j, -10:10:20j]
s = np.sin(x*y*z)/(x*y*z)

mlab.pipeline.volume(mlab.pipeline.scalar_field(x,y,z,s))
mlab.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-6073cbf1a061> in <cell line: 0>()
#       5 s = np.sin(x*y*z)/(x*y*z)
#       6
# ----> 7 mlab.pipeline.volume(mlab.pipeline.scalar_field(x,y,z,s))
#       8 mlab.show()
#
# /usr/local/lib/python3.11/dist-packages/mayavi/tools/sources.py in scalar_field(*args, **kwargs)
#    1166
#    1167     data_source = MArraySource()
# -> 1168     data_source.reset(x=x, y=y, z=z, scalars=s)
#    1169
#    1170     name = kwargs.pop('name', 'ScalarField')
#
# /usr/local/lib/python3.11/dist-packages/mayavi/tools/sources.py in reset(self, **traits)
#     389
#     390         if self.m_data is None:
# --> 391             ds = ArraySource(transpose_input_array=True)
#     392         else:
#     393             ds = self.m_data
#
# ...
